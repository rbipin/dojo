# %% [markdown]
# ### Create test json file for DF Adjustments

# %%
# Prepare Throws Test Data as Json File
import pandas as pd
import simplejson

df_transaction_types = {
    "QPCA-PC": {"transaction_name": "DFPhyCntAdj", "transaction_type": 70},
    "QPCA-PI": {"transaction_name": "DFCycCntAdj", "transaction_type": 71},
    "QPCA-BR": {"transaction_name": "DFByrReqAdj", "transaction_type": 73},
    "QPCA-OD": {"transaction_name": "DFOdtPrdAdj", "transaction_type": 77},
    "QPCA-MS": {"transaction_name": "DFMisOthAdj", "transaction_type": 79},
    "QPCA-BL": {"transaction_name": "DFMisOthAdj", "transaction_type": 79},
    "QSIA-SI": {"transaction_name": "DFSlotInAdj", "transaction_type": 74},
    "QSIA-AU": {"transaction_name": "DFSltAutAdj", "transaction_type": 81},
    "QSIA-AR": {"transaction_name": "DFRcnAutAdj", "transaction_type": 82},
}
column_mapping = {
    "ut_id": "unit",
    "evnt_typ_ct": "eventTyp",
    "evnt_adj_qt": "adjQt",
    "evnt_rsn_ct": "reasonCode",
    "in_pk_id": "innerPack",
    "transName": "transName",
    "transactionSource": "transactionSource",
    "functionalityTyp": "functionalityTyp",
}


def get_transaction_name(df_row) -> str:
    event_type = (
        ""
        if (
            str(df_row["evnt_typ_ct"]).strip() == ""
            or pd.isna(df_row["evnt_typ_ct"])
            or pd.isnull(df_row["evnt_typ_ct"])
        )
        else df_row["evnt_typ_ct"].strip()
    )
    event_reason = (
        ""
        if (
            str(df_row["evnt_rsn_ct"]).strip() == ""
            or pd.isna(df_row["evnt_rsn_ct"])
            or pd.isnull(df_row["evnt_rsn_ct"])
        )
        else df_row["evnt_rsn_ct"].strip()
    )
    transaction_key = f"{event_type}-{event_reason}"
    print(transaction_key)
    return df_transaction_types.get(transaction_key, "")


def convert_to_json(sheet_name):
    sheet_names = [sheet_name]
    if not excel_sheet_name:
        excel = pd.ExcelFile(excel_file_name)
        sheet_names = excel.sheet_names
    for sheet in sheet_names:
        print(sheet)
        records = []
        test_file_name = sheet
        df = pd.read_excel(excel_file_name, sheet_name=sheet)
        df = df.rename(columns=lambda x: x.strip())
        df.columns = map(str.lower, df.columns)  # make columns names lower case
        newdf = df.filter(list(column_mapping.keys()))  # filter to 9 columns
        # fill in transaciton name from transaction type
        for _, row in newdf.iterrows():
            transaction_detail = get_transaction_name(row)
            print(transaction_detail)
            record = {
                "unit": int(row["ut_id"]),
                "eventTyp": row["evnt_typ_ct"].strip(),
                "transName": transaction_detail["transaction_name"],
                "transTyp": transaction_detail["transaction_type"],
                "adjQt": float(row["evnt_adj_qt"]),
                "innerPack": int(row["in_pk_id"]),
                "reasonCode": row["evnt_rsn_ct"].strip(),
                "functionalityTyp": "DFAdjustment",
            }
            records.append(record)
            print(records)
        with open(f"{test_file_name}.json", "w") as outfile:  # export to json
            outfile.write(simplejson.dumps(records, ignore_nan=True, indent=4))


# start the process
excel_file_name = "./df_adjustments.xlsx"  # excel file name
# excel sheet name, if no excel sheet is mentioned it will run for all sheets
excel_sheet_name = ""
convert_to_json(excel_sheet_name)
# Out:
# QPCA_PC
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -350.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -350.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -350.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -280.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -350.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -280.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PC
# {'transaction_name': 'DFPhyCntAdj', 'transaction_type': 70}
# [{'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -360.0, 'innerPack': 3259281, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 4659938, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -60.0, 'innerPack': 5558289, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -210.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -350.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -280.0, 'innerPack': 6333567, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -140.0, 'innerPack': 6333566, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}, {'unit': 85, 'eventTyp': 'QPCA', 'transName': 'DFPhyCntAdj', 'transTyp': 70, 'adjQt': -845.0, 'innerPack': 546908, 'reasonCode': 'PC', 'functionalityTyp': 'DFAdjustment'}]
# QPCA_OD
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-OD
# {'transaction_name': 'DFOdtPrdAdj', 'transaction_type': 77}
# [{'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 6690219, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6708171, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 882, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -3.0, 'innerPack': 6651523, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 54.0, 'innerPack': 3543854, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': 1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}, {'unit': 871, 'eventTyp': 'QPCA', 'transName': 'DFOdtPrdAdj', 'transTyp': 77, 'adjQt': -1.0, 'innerPack': 4121421, 'reasonCode': 'OD', 'functionalityTyp': 'DFAdjustment'}]
# QPCA_MS
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 5881082, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 5881082, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 8.0, 'innerPack': 5026398, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 5881082, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 8.0, 'innerPack': 5026398, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 32.0, 'innerPack': 2529014, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 5881082, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 8.0, 'innerPack': 5026398, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 32.0, 'innerPack': 2529014, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 401306, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-MS
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 455612, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 1.0, 'innerPack': 4543636, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 10.0, 'innerPack': 5643097, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 5250009, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 3810042, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 5881082, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 8.0, 'innerPack': 5026398, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 32.0, 'innerPack': 2529014, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 4.0, 'innerPack': 401306, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}, {'unit': 86, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 2.0, 'innerPack': 4885700, 'reasonCode': 'MS', 'functionalityTyp': 'DFAdjustment'}]
# QPCA_BL
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 6843290, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 6843290, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3159661, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 6843290, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3159661, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 29.0, 'innerPack': 5678659, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 6843290, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3159661, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 29.0, 'innerPack': 5678659, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 3772464, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BL
# {'transaction_name': 'DFMisOthAdj', 'transaction_type': 79}
# [{'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -4.0, 'innerPack': 3637914, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': -19.0, 'innerPack': 2859930, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3026818, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 9.0, 'innerPack': 4908437, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 15.0, 'innerPack': 5689968, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 6843290, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 232.0, 'innerPack': 3159661, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 29.0, 'innerPack': 5678659, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 3772464, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}, {'unit': 805, 'eventTyp': 'QPCA', 'transName': 'DFMisOthAdj', 'transTyp': 79, 'adjQt': 116.0, 'innerPack': 5733421, 'reasonCode': 'BL', 'functionalityTyp': 'DFAdjustment'}]
# QSIA_AU
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -819.0, 'innerPack': 5400402, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# [{'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -83333333.0, 'innerPack': 4795591, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -41666666.0, 'innerPack': 4817875, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -90.0, 'innerPack': 7284530, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 84, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -819.0, 'innerPack': 5400402, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QSIA', 'transName': 'DFSltAutAdj', 'transTyp': 81, 'adjQt': -46.0, 'innerPack': 7287209, 'reasonCode': 'AU', 'functionalityTyp': 'DFAdjustment'}]
# QSIA-AU
# {'transaction_name': 'DFSltAutAdj', 'transaction_type': 81}
# ...
# QPCA-PI
# {'transaction_name': 'DFCycCntAdj', 'transaction_type': 71}
# [{'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5465324, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 7.0, 'innerPack': 401303, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 2.0, 'innerPack': 5555523, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5548939, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 1.0, 'innerPack': 4688360, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 4.0, 'innerPack': 5485716, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PI
# {'transaction_name': 'DFCycCntAdj', 'transaction_type': 71}
# [{'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5465324, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 7.0, 'innerPack': 401303, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 2.0, 'innerPack': 5555523, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5548939, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 1.0, 'innerPack': 4688360, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 4.0, 'innerPack': 5485716, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 5.0, 'innerPack': 518338, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PI
# {'transaction_name': 'DFCycCntAdj', 'transaction_type': 71}
# [{'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5465324, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 7.0, 'innerPack': 401303, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 2.0, 'innerPack': 5555523, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5548939, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 1.0, 'innerPack': 4688360, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 4.0, 'innerPack': 5485716, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 5.0, 'innerPack': 518338, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -1.0, 'innerPack': 4038641, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-PI
# {'transaction_name': 'DFCycCntAdj', 'transaction_type': 71}
# [{'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5465324, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 7.0, 'innerPack': 401303, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 2.0, 'innerPack': 5555523, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 93, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -8.0, 'innerPack': 5548939, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 1.0, 'innerPack': 4688360, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 4.0, 'innerPack': 5485716, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 5.0, 'innerPack': 518338, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': -1.0, 'innerPack': 4038641, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}, {'unit': 881, 'eventTyp': 'QPCA', 'transName': 'DFCycCntAdj', 'transTyp': 71, 'adjQt': 8.0, 'innerPack': 520333, 'reasonCode': 'PI', 'functionalityTyp': 'DFAdjustment'}]
# QPCA_BR
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -516.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -516.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -552.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -516.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -552.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -672.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -516.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -552.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -672.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -409.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]
# QPCA-BR
# {'transaction_name': 'DFByrReqAdj', 'transaction_type': 73}
# [{'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -1135.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -846.0, 'innerPack': 3602943, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -556.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -595.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -729.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 872, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -516.0, 'innerPack': 5524392, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 860, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -552.0, 'innerPack': 3213062, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -672.0, 'innerPack': 5769629, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -409.0, 'innerPack': 5524399, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}, {'unit': 89, 'eventTyp': 'QPCA', 'transName': 'DFByrReqAdj', 'transTyp': 73, 'adjQt': -255.0, 'innerPack': 3257270, 'reasonCode': 'BR', 'functionalityTyp': 'DFAdjustment'}]

# %% [markdown]
# ### Export Throws Test Data from Excel to json
#
# Script converts the excel data to json records
#
# #### Requirements
#
# 1. VSCode + jupter extension + ipykernal (autoinstalled)
# 2. Python
#     - panda `pip install pandas`
#     - openpyxl `pip install openpyxl`
#     - simplejsom `pip install simplejson`
#
# This prepares the json test data with json data in a array, remove the array[] representation manually

# %%
# Prepare Throws Test Data as Json File
import pandas as pd
import simplejson

throws_transaction_types = {
    330: "Reclamation VCB",
    331: "Reclamation Salvage",
    332: "Reclamation NDR VCB",
    333: "Reclamation NDR Salvage",
    336: "Reclamation Mis-Select",
    337: "Compactor Mis-Select",
    340: "Compactor",
    341: "Salvage",
    342: "Recall Throw",
    343: "NDR Throw",
    344: "Received Damaged",
    345: "Received Damaged Salvage",
    347: "Compactor Shrink",
    348: "Food Rescue",
    351: "Ecommerce Salvage",
    702: "Expected Loss",
    906: "Empty Package",
    385: "Empty Package",
}
column_mapping = {
    "tn_src_ut_id": "unit",
    "tn_id": "sourceAuditReference",
    "upc_id": "upc",
    "pky_src_id": "primarykey",
    "tn_boh_adj_qt": "adjQt",
    "tn_typ_id": "tran_type",
    "tn_trnsf_typ_id": "tn_trnsf_typ_id",
    "rtl_dol_adj_am": "rtlAm",
    "transName": "transName",
    "transactionSource": "transactionSource",
    "functionalityTyp": "functionalityTyp",
}


def get_transaction_name(df_row) -> str:
    transaction_type_id = (
        0
        if (
            str(df_row["tn_typ_id"]).strip() == ""
            or pd.isna(df_row["tn_typ_id"])
            or pd.isnull(df_row["tn_typ_id"])
        )
        else int(df_row["tn_typ_id"])
    )
    transaction_reference = (
        0
        if (
            str(df_row["tn_trnsf_typ_id"]).strip() == ""
            or pd.isna(df_row["tn_trnsf_typ_id"])
            or pd.isnull(df_row["tn_trnsf_typ_id"])
        )
        else int(df_row["tn_trnsf_typ_id"])
    )
    transaction_type = transaction_type_id + transaction_reference
    return throws_transaction_types.get(transaction_type, "")


def convert_to_json(sheet_name):
    sheet_names = [sheet_name]
    if not excel_sheet_name:
        excel = pd.ExcelFile(excel_file_name)
        sheet_names = excel.sheet_names
    for sheet in sheet_names:
        print(sheet)
        records = []
        test_file_name = sheet
        df = pd.read_excel(excel_file_name, sheet_name=sheet)
        df.columns = map(str.lower, df.columns)  # make columns names lower case
        newdf = df.filter(list(column_mapping.keys()))  # filter to 9 columns
        # fill in transaciton name from transaction type
        for _, row in newdf.iterrows():
            transaction_name = get_transaction_name(row)
            try:
                audit_reference = str(int(row["tn_id"]))
            except ValueError:
                audit_reference = str(row["tn_id"])
            record = {
                "unit": int(row["tn_src_ut_id"]),
                "sourceAuditReference": audit_reference,
                "upc": None,
                "adjQt": float(row["tn_boh_adj_qt"]),
                "rtlAm": float(row["rtl_dol_adj_am"]),
                "transactionSource": "SuperCenter",
                "functionalityTyp": "Throws",
                "transName": transaction_name,
            }
            upc = row["upc_id"]
            # if upc is not present, only then create primarykey
            if str(upc).strip() == "" or pd.isna(upc) or pd.isnull(upc):
                record["primarykey"] = int(row["pky_src_id"])
            else:
                record["upc"] = int(upc)
            records.append(record)
        with open(f"{test_file_name}.json", "w") as outfile:  # export to json
            outfile.write(simplejson.dumps(records, ignore_nan=True, indent=4))


# start the process
excel_file_name = "./data.xlsx"  # excel file name
# excel sheet name, if no excel sheet is mentioned it will run for all sheets
excel_sheet_name = ""
convert_to_json(excel_sheet_name)
# Out:
# T330
# T331
# T332
# T333
# T336
# T337
# T340
# T341
# T343
# T344
# T345
# T347
# T348
# T351
# T702
# T906

# %% [markdown]
# ### Create a file with Json Array for throws

# %%
# Prepare Throws Test Data as Single Json Array File
import pandas as pd
import simplejson

throws_transaction_types = {
    330: "Reclamation VCB",
    331: "Reclamation Salvage",
    332: "Reclamation NDR VCB",
    333: "Reclamation NDR Salvage",
    336: "Reclamation Mis-Select",
    337: "Compactor Mis-Select",
    340: "Compactor",
    341: "Salvage",
    342: "Recall Throw",
    343: "NDR Throw",
    344: "Received Damaged",
    345: "Received Damaged Salvage",
    347: "Compactor Shrink",
    348: "Food Rescue",
    351: "Ecommerce Salvage",
    702: "Expected Loss",
    906: "Empty Package",
    385: "Empty Package",
}
column_mapping = {
    "tn_src_ut_id": "unit",
    "tn_id": "sourceAuditReference",
    "upc_id": "upc",
    "pky_src_id": "primarykey",
    "tn_boh_adj_qt": "adjQt",
    "tn_typ_id": "tran_type",
    "tn_trnsf_typ_id": "tn_trnsf_typ_id",
    "rtl_dol_adj_am": "rtlAm",
    "transName": "transName",
    "transactionSource": "transactionSource",
    "functionalityTyp": "functionalityTyp",
}


def get_transaction_name(df_row) -> str:
    transaction_type_id = (
        0
        if (
            str(df_row["tn_typ_id"]).strip() == ""
            or pd.isna(df_row["tn_typ_id"])
            or pd.isnull(df_row["tn_typ_id"])
        )
        else int(df_row["tn_typ_id"])
    )
    transaction_reference = (
        0
        if (
            str(df_row["tn_trnsf_typ_id"]).strip() == ""
            or pd.isna(df_row["tn_trnsf_typ_id"])
            or pd.isnull(df_row["tn_trnsf_typ_id"])
        )
        else int(df_row["tn_trnsf_typ_id"])
    )
    transaction_type = transaction_type_id + transaction_reference
    return throws_transaction_types.get(transaction_type, "")


def convert_to_json(sheet_name):
    sheet_names = [sheet_name]
    if not excel_sheet_name:
        excel = pd.ExcelFile(excel_file_name)
        sheet_names = excel.sheet_names
    records = []
    for sheet in sheet_names:
        print(sheet)
        df = pd.read_excel(excel_file_name, sheet_name=sheet)
        df.columns = map(str.lower, df.columns)  # make columns names lower case
        newdf = df.filter(list(column_mapping.keys()))  # filter to 9 columns

        # fill in transaciton name from transaction type
        for _, row in newdf.iterrows():
            transaction_name = get_transaction_name(row)
            try:
                audit_reference = str(int(row["tn_id"]))
            except ValueError:
                audit_reference = str(row["tn_id"])
            record = {
                "unit": int(row["tn_src_ut_id"]),
                "sourceAuditReference": audit_reference,
                "upc": None,
                "adjQt": float(row["tn_boh_adj_qt"]),
                "rtlAm": float(row["rtl_dol_adj_am"]),
                "transactionSource": "SuperCenter",
                "functionalityTyp": "Throws",
                "transName": transaction_name,
            }
            upc = row["upc_id"]
            if str(upc).strip() == "" or pd.isna(upc) or pd.isnull(upc):
                record["primarykey"] = int(row["pky_src_id"])
            else:
                record["upc"] = int(upc)

            records.append(record)
    print(f"Total Records {len(records)}")
    with open("test_file.json", "w") as outfile:  # export to json
        outfile.write(simplejson.dumps(records, ignore_nan=True, indent=4))


# start the process
excel_file_name = "./data.xlsx"  # excel file name
# excel sheet name, if no excel sheet is mentioned it will run for all sheets
excel_sheet_name = ""
convert_to_json(excel_sheet_name)
# Out:
# T330
# T331
# T332
# T333
# T336
# T337
# T340
# T341
# T343
# T344
# T345
# T347
# T348
# T351
# T702
# T906
# Total Records 14419
